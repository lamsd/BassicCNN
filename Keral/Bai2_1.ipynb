# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.datasets import boston_housing
import matplotlib.pyplot as plt

# %%
(X_train, y_train), (X_test, y_test) = boston_housing.load_data()

# %%
X_val = X_train[300:,]
y_val = y_train[300:,]
X_traind = X_train[:300,]
y_traind = y_train[:300,]

# %%
N_eposh = 200

# %%
import os
import shutil
import csv
import sys
def saving_data(index, data1):
    pathname = "./csv_data.csv"
    if index == 0:
        if not os.path.isfile(pathname):
            print("Path direction")
            return 
        os.remove(pathname)
        print("Removing data the system")
        return
    with open(pathname, "+a") as f:
        writer = csv.writer(f)
        writer.writerow(data1)
        f.close()
        
saving_data(0, [])
# Out:
# Removing data the system

# %% [markdown]
# ## 1. Basic data model 1.

# %%
model = Sequential()
model.add(Dense(13, input_dim=13, kernel_initializer='normal', activation='relu'))
model.add(Dense(6, kernel_initializer='normal', activation='relu'))
model.add(Dense(1, kernel_initializer='normal'))
model.compile(loss='mean_squared_error', optimizer='adam', metrics = ['mean_absolute_percentage_error'])
model.summary()

hist = model.fit(X_traind, y_traind, batch_size=32, epochs=N_eposh, validation_data=(X_val, y_val), verbose=0)

plt.plot(hist.history['mean_absolute_percentage_error'])
plt.plot(hist.history['val_mean_absolute_percentage_error'])
plt.xlabel("epochs")
plt.ylabel("%")
plt.title("Mean Absolute % title")
plt.legend(["train", "test"], loc='upper left')
plt.show()

result = model.evaluate(X_test, y_test)
datacode_list = []
datacode_list.append("1-normal-rule")
for i in range(len(model.metrics_names)):
    print("value: ", model.metrics_names[i], ":", result[i])
    datacode_list.append(result[i])
saving_data(1, datacode_list )
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 13)                182
#
#  dense_1 (Dense)             (None, 6)                 84
#
#  dense_2 (Dense)             (None, 1)                 7
#
# ...
# Total params: 273
# Trainable params: 273
# Non-trainable params: 0
# _________________________________________________________________
# 4/4 [==============================] - 0s 2ms/step - loss: 37.2772 - mean_absolute_percentage_error: 20.2012
# value:  loss : 37.27717208862305
# value:  mean_absolute_percentage_error : 20.20119285583496

# %% [markdown]
# ## 2. Basic model 2.

# %%
model = Sequential()
model.add(Dense(13, input_dim=13, activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam', metrics = ['mean_absolute_percentage_error'])
model.summary()

hist_delete_kernel = model.fit(X_traind, y_traind, batch_size=32, epochs=N_eposh, validation_data=(X_val, y_val), verbose=0)

plt.plot(hist_delete_kernel.history['mean_absolute_percentage_error'])
plt.plot(hist_delete_kernel.history['val_mean_absolute_percentage_error'])
plt.xlabel("epochs")
plt.ylabel("%")
plt.title("Mean Absolute % title")
plt.legend(["train", "test"], loc='upper left')
plt.show()

result = model.evaluate(X_test, y_test)
datacode_list = []
datacode_list.append("2-None-relu")
for i in range(len(model.metrics_names)):
    print("value: ", model.metrics_names[i], ":", result[i])
    datacode_list.append(result[i])
saving_data(1, datacode_list )
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 13)                182
#
#  dense_4 (Dense)             (None, 6)                 84
#
#  dense_5 (Dense)             (None, 1)                 7
#
# ...
# Total params: 273
# Trainable params: 273
# Non-trainable params: 0
# _________________________________________________________________
# 4/4 [==============================] - 0s 3ms/step - loss: 52.6640 - mean_absolute_percentage_error: 25.6249
# value:  loss : 52.66398239135742
# value:  mean_absolute_percentage_error : 25.624897003173828

# %% [markdown]
# ## 3. Basic Model 3.

# %%
model = Sequential()
model.add(Dense(13, input_dim=13, kernel_initializer='random_normal', bias_initializer='ones', activation='relu'))
model.add(Dense(6, kernel_initializer='random_normal', bias_initializer='ones', activation='relu'))
model.add(Dense(1, kernel_initializer='random_normal', bias_initializer='ones'))
model.compile(loss='mean_squared_error', optimizer='adam', metrics = ['mean_absolute_percentage_error'])
model.summary()

hist_delete_kernel = model.fit(X_traind, y_traind, batch_size=32, epochs=N_eposh, validation_data=(X_val, y_val), verbose=0)

plt.plot(hist_delete_kernel.history['mean_absolute_percentage_error'])
plt.plot(hist_delete_kernel.history['val_mean_absolute_percentage_error'])
plt.xlabel("epochs")
plt.ylabel("%")
plt.title("Mean Absolute % title")
plt.legend(["train", "test"], loc='upper left')
plt.show()

result = model.evaluate(X_test, y_test)
datacode_list = []
datacode_list.append("3-rad-one")
for i in range(len(model.metrics_names)):
    print("value: ", model.metrics_names[i], ":", result[i])
    datacode_list.append(result[i])
saving_data(1, datacode_list )
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 13)                182
#
#  dense_7 (Dense)             (None, 6)                 84
#
#  dense_8 (Dense)             (None, 1)                 7
#
# ...
# Total params: 273
# Trainable params: 273
# Non-trainable params: 0
# _________________________________________________________________
# 4/4 [==============================] - 0s 3ms/step - loss: 37.4704 - mean_absolute_percentage_error: 22.2318
# value:  loss : 37.47043991088867
# value:  mean_absolute_percentage_error : 22.231813430786133

# %% [markdown]
# ## 4. Basic model 4.

# %%
model = Sequential()
model.add(Dense(13, input_dim=13, kernel_initializer='normal', bias_initializer='ones', activation='relu'))
model.add(Dense(6, kernel_initializer='normal', bias_initializer='ones', activation='relu'))
model.add(Dense(1, kernel_initializer='normal', bias_initializer='ones'))
model.compile(loss='mean_squared_error', optimizer='adam', metrics = ['mean_absolute_percentage_error'])
model.summary()

hist_delete_kernel = model.fit(X_traind, y_traind, batch_size=32, epochs=N_eposh, validation_data=(X_val, y_val), verbose=0)

plt.plot(hist_delete_kernel.history['mean_absolute_percentage_error'])
plt.plot(hist_delete_kernel.history['val_mean_absolute_percentage_error'])
plt.xlabel("epochs")
plt.ylabel("%")
plt.title("Mean Absolute % title")
plt.legend(["train", "test"], loc='upper left')
plt.show()

result = model.evaluate(X_test, y_test)
datacode_list = []
datacode_list.append("4-nor-ones")
for i in range(len(model.metrics_names)):
    print("value: ", model.metrics_names[i], ":", result[i])
    datacode_list.append(result[i])
saving_data(1, datacode_list )
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_9 (Dense)             (None, 13)                182
#
#  dense_10 (Dense)            (None, 6)                 84
#
#  dense_11 (Dense)            (None, 1)                 7
#
# ...
# Total params: 273
# Trainable params: 273
# Non-trainable params: 0
# _________________________________________________________________
# 4/4 [==============================] - 0s 2ms/step - loss: 29.5519 - mean_absolute_percentage_error: 19.2629
# value:  loss : 29.551942825317383
# value:  mean_absolute_percentage_error : 19.262903213500977

# %% [markdown]
# ## 5. Basic model 5.

# %%
model = Sequential()
model.add(Dense(13, input_dim=13, kernel_initializer='glorot_uniform', bias_initializer='ones', activation='relu'))
model.add(Dense(6, kernel_initializer='glorot_uniform', bias_initializer='ones', activation='relu'))
model.add(Dense(1, kernel_initializer='glorot_uniform', bias_initializer='ones'))
model.compile(loss='mean_squared_error', optimizer='adam', metrics = ['mean_absolute_percentage_error'])
model.summary()

hist_delete_kernel = model.fit(X_traind, y_traind, batch_size=32, epochs=N_eposh, validation_data=(X_val, y_val), verbose=0)

plt.plot(hist_delete_kernel.history['mean_absolute_percentage_error'])
plt.plot(hist_delete_kernel.history['val_mean_absolute_percentage_error'])
plt.xlabel("epochs")
plt.ylabel("%")
plt.title("Mean Absolute % title")
plt.legend(["train", "test"], loc='upper left')
plt.show()

result = model.evaluate(X_test, y_test)
datacode_list = []
datacode_list.append("5-glui_relu")
for i in range(len(model.metrics_names)):
    print("value: ", model.metrics_names[i], ":", result[i])
    datacode_list.append(result[i])
saving_data(1, datacode_list )
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_12 (Dense)            (None, 13)                182
#
#  dense_13 (Dense)            (None, 6)                 84
#
#  dense_14 (Dense)            (None, 1)                 7
#
# ...
# Total params: 273
# Trainable params: 273
# Non-trainable params: 0
# _________________________________________________________________
# 4/4 [==============================] - 0s 2ms/step - loss: 65.0251 - mean_absolute_percentage_error: 31.4680
# value:  loss : 65.02507781982422
# value:  mean_absolute_percentage_error : 31.4680233001709

# %% [markdown]
# ## 6. Basic model 6.

# %%
model = Sequential()
model.add(Dense(13, input_dim=13, kernel_initializer='glorot_uniform', bias_initializer='zeros', activation='relu'))
model.add(Dense(6, kernel_initializer='glorot_uniform', bias_initializer='zeros', activation='relu'))
model.add(Dense(1, kernel_initializer='glorot_uniform', bias_initializer='zeros'))
model.compile(loss='mean_squared_error', optimizer='adam', metrics = ['mean_absolute_percentage_error'])
model.summary()

hist_delete_kernel = model.fit(X_traind, y_traind, batch_size=32, epochs=N_eposh, validation_data=(X_val, y_val), verbose=0)

plt.plot(hist_delete_kernel.history['mean_absolute_percentage_error'])
plt.plot(hist_delete_kernel.history['val_mean_absolute_percentage_error'])
plt.xlabel("epochs")
plt.ylabel("%")
plt.title("Mean Absolute % title")
plt.legend(["train", "test"], loc='upper left')
plt.show()

result = model.evaluate(X_test, y_test)
datacode_list = []
datacode_list.append("6-glui-zero")
for i in range(len(model.metrics_names)):
    print("value: ", model.metrics_names[i], ":", result[i])
    datacode_list.append(result[i])
saving_data(1, datacode_list )
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_15 (Dense)            (None, 13)                182
#
#  dense_16 (Dense)            (None, 6)                 84
#
#  dense_17 (Dense)            (None, 1)                 7
#
# ...
# Total params: 273
# Trainable params: 273
# Non-trainable params: 0
# _________________________________________________________________
# 4/4 [==============================] - 0s 2ms/step - loss: 39.9696 - mean_absolute_percentage_error: 24.1915
# value:  loss : 39.96956253051758
# value:  mean_absolute_percentage_error : 24.191530227661133

# %% [markdown]
# ## 7. Basic model 7.

# %%
model = Sequential()
model.add(Dense(13, input_dim=13, kernel_initializer='GlorotUniform', bias_initializer='zeros', activation='relu'))
model.add(Dense(6, kernel_initializer='GlorotUniform', bias_initializer='zeros', activation='relu'))
model.add(Dense(1, kernel_initializer='GlorotUniform', bias_initializer='zeros'))
model.compile(loss='mean_squared_error', optimizer='adam', metrics = ['mean_absolute_percentage_error'])
model.summary()

hist_delete_kernel = model.fit(X_traind, y_traind, batch_size=32, epochs=N_eposh, validation_data=(X_val, y_val), verbose=0)

plt.plot(hist_delete_kernel.history['mean_absolute_percentage_error'])
plt.plot(hist_delete_kernel.history['val_mean_absolute_percentage_error'])
plt.xlabel("epochs")
plt.ylabel("%")
plt.title("Mean Absolute % title")
plt.legend(["train", "test"], loc='upper left')
plt.show()

result = model.evaluate(X_test, y_test)
datacode_list = []
datacode_list.append("7-Glui-zero")
for i in range(len(model.metrics_names)):
    print("value: ", model.metrics_names[i], ":", result[i])
    datacode_list.append(result[i])
saving_data(1, datacode_list )
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_18 (Dense)            (None, 13)                182
#
#  dense_19 (Dense)            (None, 6)                 84
#
#  dense_20 (Dense)            (None, 1)                 7
#
# ...
# Total params: 273
# Trainable params: 273
# Non-trainable params: 0
# _________________________________________________________________
# 4/4 [==============================] - 0s 2ms/step - loss: 41.6536 - mean_absolute_percentage_error: 22.7050
# value:  loss : 41.65363693237305
# value:  mean_absolute_percentage_error : 22.704992294311523

# %% [markdown]
# ## 8. Basic model 8.

# %%
model = Sequential()
model.add(Dense(13, input_dim=13, kernel_initializer='glorot_uniform', bias_initializer='zeros', activation='relu'))
model.add(Dense(13, kernel_initializer='glorot_uniform', bias_initializer='zeros', activation='relu'))
model.add(Dense(13, kernel_initializer='glorot_uniform', bias_initializer='zeros', activation='relu'))
model.add(Dense(13, kernel_initializer='glorot_uniform', bias_initializer='zeros', activation='relu'))
model.add(Dense(1, kernel_initializer='glorot_uniform', bias_initializer='zeros'))
model.compile(loss='mean_squared_error', optimizer='adam', metrics = ['mean_absolute_percentage_error'])
model.summary()

hist_delete_kernel = model.fit(X_traind, y_traind, batch_size=32, epochs=N_eposh, validation_data=(X_val, y_val), verbose=0)

plt.plot(hist_delete_kernel.history['mean_absolute_percentage_error'])
plt.plot(hist_delete_kernel.history['val_mean_absolute_percentage_error'])
plt.xlabel("epochs")
plt.ylabel("%")
plt.title("Mean Absolute % title")
plt.legend(["train", "test"], loc='upper left')
plt.show()

result = model.evaluate(X_test, y_test)
datacode_list = []
datacode_list.append("8-mul-glui-zero")
for i in range(len(model.metrics_names)):
    print("value: ", model.metrics_names[i], ":", result[i])
    datacode_list.append(result[i])
saving_data(1, datacode_list )
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_21 (Dense)            (None, 13)                182
#
#  dense_22 (Dense)            (None, 13)                182
#
#  dense_23 (Dense)            (None, 13)                182
#
#  dense_24 (Dense)            (None, 13)                182
#
#  dense_25 (Dense)            (None, 1)                 14
#
# ...
# Total params: 742
# Trainable params: 742
# Non-trainable params: 0
# _________________________________________________________________
# 4/4 [==============================] - 0s 3ms/step - loss: 31.5812 - mean_absolute_percentage_error: 19.0628
# value:  loss : 31.581207275390625
# value:  mean_absolute_percentage_error : 19.06279182434082

# %% [markdown]
# ## 9. Basic Modeling 9.

# %%
model = Sequential()
model.add(Dense(13, input_dim=13, kernel_initializer='glorot_uniform', bias_initializer='ones', activation='relu'))
model.add(Dense(13, kernel_initializer='glorot_uniform', bias_initializer='ones', activation='relu'))
model.add(Dense(13, kernel_initializer='glorot_uniform', bias_initializer='ones', activation='relu'))
model.add(Dense(13, kernel_initializer='glorot_uniform', bias_initializer='ones', activation='relu'))
model.add(Dense(1, kernel_initializer='glorot_uniform', bias_initializer='ones'))
model.compile(loss='mean_squared_error', optimizer='adam', metrics = ['mean_absolute_percentage_error'])
model.summary()

hist_delete_kernel = model.fit(X_traind, y_traind, batch_size=32, epochs=N_eposh, validation_data=(X_val, y_val), verbose=0)

plt.plot(hist_delete_kernel.history['mean_absolute_percentage_error'])
plt.plot(hist_delete_kernel.history['val_mean_absolute_percentage_error'])
plt.xlabel("epochs")
plt.ylabel("%")
plt.title("Mean Absolute % title")
plt.legend(["train", "test"], loc='upper left')
plt.show()

result = model.evaluate(X_test, y_test)
datacode_list = []
datacode_list.append("9-mul-glui-ones")
for i in range(len(model.metrics_names)):
    print("value: ", model.metrics_names[i], ":", result[i])
    datacode_list.append(result[i])
saving_data(1, datacode_list )
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_26 (Dense)            (None, 13)                182
#
#  dense_27 (Dense)            (None, 13)                182
#
#  dense_28 (Dense)            (None, 13)                182
#
#  dense_29 (Dense)            (None, 13)                182
#
#  dense_30 (Dense)            (None, 1)                 14
#
# ...
# Total params: 742
# Trainable params: 742
# Non-trainable params: 0
# _________________________________________________________________
# 4/4 [==============================] - 0s 3ms/step - loss: 33.3483 - mean_absolute_percentage_error: 19.5785
# value:  loss : 33.34832763671875
# value:  mean_absolute_percentage_error : 19.578474044799805

# %% [markdown]
# ## 10. Basic Modeling 10.

# %%
model = Sequential()
model.add(Dense(13, input_dim=13, kernel_initializer='normal', bias_initializer='ones', activation='relu'))
model.add(Dense(13, kernel_initializer='normal', bias_initializer='ones', activation='relu'))
model.add(Dense(13, kernel_initializer='normal', bias_initializer='ones', activation='relu'))
model.add(Dense(13, kernel_initializer='normal', bias_initializer='ones', activation='relu'))
model.add(Dense(1, kernel_initializer='normal', bias_initializer='ones'))
model.compile(loss='mean_squared_error', optimizer='adam', metrics = ['mean_absolute_percentage_error'])
model.summary()

hist_delete_kernel = model.fit(X_traind, y_traind, batch_size=32, epochs=N_eposh, validation_data=(X_val, y_val), verbose=0)

plt.plot(hist_delete_kernel.history['mean_absolute_percentage_error'])
plt.plot(hist_delete_kernel.history['val_mean_absolute_percentage_error'])
plt.xlabel("epochs")
plt.ylabel("%")
plt.title("Mean Absolute % title")
plt.legend(["train", "test"], loc='upper left')
plt.show()

result = model.evaluate(X_test, y_test)
datacode_list = []
datacode_list.append("10-mul-normal-ones")
for i in range(len(model.metrics_names)):
    print("value: ", model.metrics_names[i], ":", result[i])
    datacode_list.append(result[i])
saving_data(1, datacode_list )
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_31 (Dense)            (None, 13)                182
#
#  dense_32 (Dense)            (None, 13)                182
#
#  dense_33 (Dense)            (None, 13)                182
#
#  dense_34 (Dense)            (None, 13)                182
#
#  dense_35 (Dense)            (None, 1)                 14
#
# ...
# Total params: 742
# Trainable params: 742
# Non-trainable params: 0
# _________________________________________________________________
# 4/4 [==============================] - 0s 2ms/step - loss: 29.7754 - mean_absolute_percentage_error: 18.5840
# value:  loss : 29.775362014770508
# value:  mean_absolute_percentage_error : 18.584001541137695

# %% [markdown]
# ## 11. Basic Modeling 11.

# %%
model = Sequential()
model.add(Dense(64, input_dim=13, kernel_initializer='normal', bias_initializer='ones', activation='relu'))
model.add(Dense(32, kernel_initializer='normal', bias_initializer='ones', activation='relu'))
model.add(Dense(16, kernel_initializer='normal', bias_initializer='ones', activation='relu'))
model.add(Dense(8, kernel_initializer='normal', bias_initializer='ones', activation='relu'))
model.add(Dense(4, kernel_initializer='normal', bias_initializer='ones', activation='relu'))
model.add(Dense(2, kernel_initializer='normal', bias_initializer='ones', activation='relu'))
model.add(Dense(1, kernel_initializer='normal', bias_initializer='ones'))
model.compile(loss='mean_squared_error', optimizer='adam', metrics = ['mean_absolute_percentage_error'])
model.summary()

hist_delete_kernel = model.fit(X_traind, y_traind, batch_size=32, epochs=1000, validation_data=(X_val, y_val), verbose=0)

plt.plot(hist_delete_kernel.history['mean_absolute_percentage_error'])
plt.plot(hist_delete_kernel.history['val_mean_absolute_percentage_error'])
plt.xlabel("epochs")
plt.ylabel("%")
plt.title("Mean Absolute % title")
plt.legend(["train", "test"], loc='upper left')
plt.show()

result = model.evaluate(X_test, y_test)
datacode_list = []
datacode_list.append("11-mul-normal-ones")
for i in range(len(model.metrics_names)):
    print("value: ", model.metrics_names[i], ":", result[i])
    datacode_list.append(result[i])
saving_data(1, datacode_list )
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_67 (Dense)            (None, 64)                896
#
#  dense_68 (Dense)            (None, 32)                2080
#
#  dense_69 (Dense)            (None, 16)                528
#
#  dense_70 (Dense)            (None, 8)                 136
#
#  dense_71 (Dense)            (None, 4)                 36
#
#  dense_72 (Dense)            (None, 2)                 10
#
#  dense_73 (Dense)            (None, 1)                 3
#
# ...
# Total params: 3,689
# Trainable params: 3,689
# Non-trainable params: 0
# _________________________________________________________________
# 4/4 [==============================] - 0s 3ms/step - loss: 23.3870 - mean_absolute_percentage_error: 16.1862
# value:  loss : 23.386964797973633
# value:  mean_absolute_percentage_error : 16.186216354370117

# %% [markdown]
# ### 12. Basic Modeling 12

# %%
model = Sequential()
model.add(Dense(13, input_dim=13, kernel_initializer='normal', bias_initializer='ones', activation='linear'))
model.add(Dense(13, kernel_initializer='normal', bias_initializer='ones', activation='linear'))
model.add(Dense(13, kernel_initializer='normal', bias_initializer='ones', activation='linear'))
model.add(Dense(13, kernel_initializer='normal', bias_initializer='ones', activation='linear'))
model.add(Dense(1, kernel_initializer='normal', bias_initializer='ones', activation='linear'))
model.compile(loss='mean_squared_error', optimizer='adam', metrics = ['mean_absolute_percentage_error'])
model.summary()

hist_delete_kernel = model.fit(X_traind, y_traind, batch_size=32, epochs=1000, validation_data=(X_val, y_val), verbose=0)

plt.plot(hist_delete_kernel.history['mean_absolute_percentage_error'])
plt.plot(hist_delete_kernel.history['val_mean_absolute_percentage_error'])
plt.xlabel("epochs")
plt.ylabel("%")
plt.title("Mean Absolute % title")
plt.legend(["train", "test"], loc='upper left')
plt.show()

result = model.evaluate(X_test, y_test)
datacode_list = []
datacode_list.append("11-mul-normal-ones")
for i in range(len(model.metrics_names)):
    print("value: ", model.metrics_names[i], ":", result[i])
    datacode_list.append(result[i])
saving_data(1, datacode_list )
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_81 (Dense)            (None, 13)                182
#
#  dense_82 (Dense)            (None, 13)                182
#
#  dense_83 (Dense)            (None, 13)                182
#
#  dense_84 (Dense)            (None, 13)                182
#
#  dense_85 (Dense)            (None, 1)                 14
#
# ...
# Total params: 742
# Trainable params: 742
# Non-trainable params: 0
# _________________________________________________________________
# 4/4 [==============================] - 0s 3ms/step - loss: 22.2254 - mean_absolute_percentage_error: 17.2014
# value:  loss : 22.225351333618164
# value:  mean_absolute_percentage_error : 17.201435089111328

# %% [markdown]
# ## Display the formatl

# %%
import matplotlib.pyplot as plt
import pandas as pd

index_name = ["IndexA", "Loss", "ARG"]
data = pd.read_csv(r"csv_data.csv", delimiter=",", names=index_name )
data_loss = data["Loss"]
data_ARG = data["ARG"]

# %%
# data[["Index", "Loss", "ARG"]].plot(x="Index", kind="bar")
data.plot(x="IndexA", y=["Loss", "ARG"], kind="bar", figsize=(20, 10), title="Index for the loss and ARG")
# Out:
# <AxesSubplot:title={'center':'Index for the loss and ARG'}, xlabel='IndexA'>

# %%
data1 = []
for i in range(100):
    pred = model.predict(X_test[i].reshape(1, 13))
    absdata = abs(y_test[i]-pred[0][0])
    data1.append(absdata)
    # print("{0} - {1} = {2}".format(y_test[i], pred[0][0], absdata))

# %%
df = pd.Series(data1)
df.describe()
# Out:
# count    100.000000
# mean       3.415531
# std        3.284020
# min        0.140319
# 25%        1.359334
# 50%        2.391537
# 75%        4.105330
# max       16.649877
# dtype: float64

# %%
plt.figure(figsize=(20, 10))
plt.hist(x=df, bins='auto', color='#0504aa', alpha=0.7, rwidth=1.0)
plt.grid(axis='y', alpha=0.75)
plt.xlabel('Value')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
sizes = [df[(df>5.0) & (df<40.0)].count(), df[(df<=5.0)].count()]
explode = (0, 0.1)
labels = [ '>5.0', '< 5.0']
plt.figure(figsize=(20, 10))
plt.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90)
plt.legend()
plt.show()
